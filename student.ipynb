# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Mario Mocombe
# * Student pace: self paced (flex)
# * Scheduled project review date/time: Mon May 22, 2023 1:30pm – 2:15pm
# * Instructor name: Abhineet Kulkarni
# * Blog post URL: https://medium.com/@mario.mocombe/minority-report-pitfalls-of-predictive-policing-fbfb34e0f598

# %% [markdown]
# # Microsoft Movie Studios
#
# Author: Mario Mocombe

# %% [markdown]
# **Overview**
#
# Microsoft is creating a new movie studio and is inquiring about what types of films are currently doing the best at the box office.  The datasets used in answering the business problem are from movie websites and contain box office information. Methods used were exploratory data analysis, data cleaning, and data manipulation.  The data shows that the highest grossing genre of films are Adventure, Action, and Comedy.  The highest grossing time of the year for movie releases is May.  There is also a positive correlation between a film's production budget and its profits.  Ideally, we should make it a priority to hire Christopher Nolan as film director.

# %% [markdown]
# ## Business Problem
#
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.
#
# Questions to consider:
#
# 1. What are the highest grossing genre of movies?
# 2. What time of the year is best to release a movie?
# 3. Is there a correlation between budget and profit?
# 4. Who are fan favorite directors that we should look to hire?
#
# These questions were considered in order to maximize studio success.  Profits are one marker of a film's success, telling us whether or not the film was financially worth pursuing.  Finding out whether a large budget is favorable will aid the studio into making informed decisions.  Data on the highest grossing genres will help Microsoft Studios narrow down on what type of films to invest in.  The release window also influences a film's success.  It's key that the studio releases it at a time where the most people will go see it.  Finally, it's important to choose a proven visionary for the director's chair.

# %% [markdown]
# ## Data Understanding
# Note that this data may not reflect the most up-to-date box office information.
#
# 1) im.db.zip
#
#     A zipped SQLite database containing movie data from the website Internet Movie Data Base. There is information on genre, online user votes, average user ratings, roles of people involved in the film etc... The most relevant tables are movie_basics (146144 rows × 6 columns), movie_ratings (73856 rows × 3 columns), and persons (606648 rows × 5 columns)
#
# 2) tn.movie_budgets.csv.gz
#
#     A compressed CSV file containing box office data, release dates, and budget data from the website The Numbers.  Database dimensions are 5782 rows × 6 columns.

# %%
##Import Standard Packages
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # 1. What are the highest grossing genres of movies?

# %% [markdown]
# ## Connect to the IMDB database

# %%
# unzip the imdb database file
import zipfile
with zipfile.ZipFile('zippedData/im.db.zip', 'r') as zip_ref:
    zip_ref.extractall('zippedData')

# %%
# make a connection with the IMDB DATABASE using SQLite3
conn = sqlite3.connect('zippedData/im.db')

# %%
# set up a cursor in order to browse through the database.
# A cursor object is what can actually execute SQL commands. You create it by calling .cursor() on the connection.

cur = conn.cursor()

# This is a special query for finding the table names. 
cur.execute("""SELECT name FROM sqlite_master WHERE type = 'table';""")

# %%
# Use the fetchall method to find out the table names
# Fetch the result and store it in table_names
table_names = cur.fetchall()
table_names
# Out:
# [('movie_basics',),
#  ('directors',),
#  ('known_for',),
#  ('movie_akas',),
#  ('movie_ratings',),
#  ('persons',),
#  ('principals',),
#  ('writers',)]

# %%
# use the pd.read_sql function to generate a dataframe
pd.read_sql("SELECT * FROM movie_basics;", conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
# generate movie ratings table
pd.read_sql("SELECT * FROM movie_ratings ORDER BY movie_id;", conn)
# Out:
#         movie_id  averagerating  numvotes
# 0      tt0063540            7.0        77
# 1      tt0066787            7.2        43
# 2      tt0069049            6.9      4517
# 3      tt0069204            6.1        13
# 4      tt0100275            6.5       119
# ...          ...            ...       ...
# 73851  tt9913084            6.2         6
# 73852  tt9914286            8.7       136
# 73853  tt9914642            8.5         8
# 73854  tt9914942            6.6         5
# 73855  tt9916160            6.5        11
#
# [73856 rows x 3 columns]

# %%
# generate persons table
pd.read_sql("SELECT * FROM persons;", conn)
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
# [606648 rows x 5 columns]

# %% [markdown]
# ## Join Tables

# %%
# select relevant columns and join tables using a shared column
# filter out lesser popular titles

d = """
SELECT primary_title, genres, category, primary_name, averagerating, numvotes 
FROM principals
JOIN movie_ratings
USING (movie_id)
JOIN movie_basics
USING (movie_id)
JOIN persons
USING (person_id)
WHERE category = "director"
AND numvotes > 63000
ORDER BY numvotes DESC;
"""
imdb = pd.read_sql(d, conn)

# %%
#use exploratory data analysis
imdb.head(20)
# Out:
#                                    primary_title                      genres  \
# 0                                      Inception     Action,Adventure,Sci-Fi
# 1                          The Dark Knight Rises             Action,Thriller
# 2                                   Interstellar      Adventure,Drama,Sci-Fi
# 3                               Django Unchained               Drama,Western
# 4                                   The Avengers     Action,Adventure,Sci-Fi
# 5                        The Wolf of Wall Street       Biography,Crime,Drama
# 6                                 Shutter Island            Mystery,Thriller
# 7                        Guardians of the Galaxy     Action,Adventure,Comedy
# 8                                       Deadpool     Action,Adventure,Comedy
# 9                               The Hunger Games     Action,Adventure,Sci-Fi
# 10    Star Wars: Episode VII - The Force Awakens    Action,Adventure,Fantasy
# 11                            Mad Max: Fury Road     Action,Adventure,Sci-Fi
# 12                                     Gone Girl      Drama,Mystery,Thriller
# 13             The Hobbit: An Unexpected Journey    Adventure,Family,Fantasy
# 14                                       Gravity       Drama,Sci-Fi,Thriller
# 15                                    Iron Man 3     Action,Adventure,Sci-Fi
# 16  Harry Potter and the Deathly Hallows: Part 2     Adventure,Drama,Fantasy
# 17                                          Thor    Action,Adventure,Fantasy
# 18                                   Toy Story 3  Adventure,Animation,Comedy
# 19                                   The Martian      Adventure,Drama,Sci-Fi
#
#     category       primary_name  averagerating  numvotes
# 0   director  Christopher Nolan            8.8   1841066
# 1   director  Christopher Nolan            8.4   1387769
# 2   director  Christopher Nolan            8.6   1299334
# 3   director  Quentin Tarantino            8.4   1211405
# 4   director        Joss Whedon            8.1   1183655
# 5   director    Martin Scorsese            8.2   1035358
# 6   director    Martin Scorsese            8.1   1005960
# 7   director         James Gunn            8.1    948394
# 8   director         Tim Miller            8.0    820847
# 9   director          Gary Ross            7.2    795227
# 10  director        J.J. Abrams            8.0    784780
# 11  director      George Miller            8.1    780910
# 12  director      David Fincher            8.1    761592
# 13  director      Peter Jackson            7.9    719629
# 14  director     Alfonso Cuarón            7.7    710018
# 15  director        Shane Black            7.2    692794
# 16  director        David Yates            8.1    691835
# 17  director    Kenneth Branagh            7.0    683264
# 18  director        Lee Unkrich            8.3    682218
# 19  director       Ridley Scott            8.0    680116

# %%
#set the imdb index to 'primary_title'
imdb.set_index('primary_title', inplace=True)

# %%
# .info provides a useful overview of the data
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 985 entries, Inception to The Death of Stalin
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   genres         985 non-null    object
#  1   category       985 non-null    object
#  2   primary_name   985 non-null    object
#  3   averagerating  985 non-null    float64
#  4   numvotes       985 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 46.2+ KB

# %% [markdown]
# Some films are listed more than once due to having multiple directors.  Where this is the case, we are going to keep the first row that mentions the film and drop the duplicate rows:

# %%
imdb = imdb[~imdb.index.duplicated(keep='first')]

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899 entries, Inception to The Death of Stalin
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   genres         899 non-null    object
#  1   category       899 non-null    object
#  2   primary_name   899 non-null    object
#  3   averagerating  899 non-null    float64
#  4   numvotes       899 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ KB

# %%
# .describe() calculates the basic summary statistics for each column
imdb.describe()
# Out:
#        averagerating      numvotes
# count     899.000000  8.990000e+02
# mean        6.806674  2.022624e+05
# std         0.841107  1.797643e+05
# min         1.600000  6.315600e+04
# 25%         6.300000  8.874600e+04
# 50%         6.800000  1.364470e+05
# 75%         7.400000  2.365815e+05
# max         9.300000  1.841066e+06

# %% [markdown]
# ## The Numbers Database

# %%
# Load up the second dataframe, THE NUMBERS, with Pandas.
numbers = pd.read_csv("zippedData/tn.movie_budgets.csv.gz")
numbers
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
# id and domestic gross are irrelevant to our current question and can be dropped:
numbers = numbers.drop(['id', 'domestic_gross'], axis=1)

# %%
numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   worldwide_gross    5782 non-null   object
# dtypes: object(4)
# memory usage: 180.8+ KB

# %% [markdown]
# The production_budget and worldwide_gross columns are in the form of a string.  We are going to convert these columns into the float dtype since we are dealing with numbers.

# %%
# convert production_budget column into a float. Replace commas and $ signs to avoid errors
numbers['production_budget'] = numbers['production_budget'].apply(lambda x: x.replace(',', '').replace('$','')).astype(float)

# %%
# convert worldwide_gross column into a float. Replace commas and $ signs to avoid errors
numbers['worldwide_gross'] = numbers['worldwide_gross'].apply(lambda x: x.replace(',', '').replace('$','')).astype(float)

# %%
# set the index to the 'movie' column
numbers.set_index('movie', inplace=True)

# %%
# check to see if the changes were made
numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5782 entries, Avatar to My Date With Drew
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   production_budget  5782 non-null   float64
#  2   worldwide_gross    5782 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 180.7+ KB

# %% [markdown]
# ## Joining Dataframes

# %%
# join the two dataframes using an inner join
joined_df = imdb.join(numbers, how='inner')

joined_df
# Out:
#                                                 genres  category  \
# 10 Cloverfield Lane               Drama,Horror,Mystery  director
# 12 Years a Slave               Biography,Drama,History  director
# 127 Hours                    Adventure,Biography,Drama  director
# 2 Guns                             Action,Comedy,Crime  director
# 21 Jump Street                     Action,Comedy,Crime  director
# ...                                                ...       ...
# Your Highness                 Adventure,Comedy,Fantasy  director
# Youth                               Comedy,Drama,Music  director
# Zero Dark Thirty                        Drama,Thriller  director
# Zootopia                    Adventure,Animation,Comedy  director
# xXx: Return of Xander Cage   Action,Adventure,Thriller  director
#
#                                   primary_name  averagerating  numvotes  \
# 10 Cloverfield Lane           Dan Trachtenberg            7.2    260383
# 12 Years a Slave                 Steve McQueen            8.1    577301
# 127 Hours                          Danny Boyle            7.6    323949
# 2 Guns                       Baltasar Kormákur            6.7    182025
# 21 Jump Street                       Phil Lord            7.2    477771
# ...                                        ...            ...       ...
# Your Highness               David Gordon Green            5.5     92940
# Youth                         Paolo Sorrentino            7.3     64418
# Zero Dark Thirty               Kathryn Bigelow            7.4    251072
# Zootopia                          Byron Howard            8.0    383446
# xXx: Return of Xander Cage         D.J. Caruso            5.2     77976
#
#                             release_date  production_budget  worldwide_gross
# 10 Cloverfield Lane         Mar 11, 2016          5000000.0     1.082864e+08
# 12 Years a Slave            Oct 18, 2013         20000000.0     1.810253e+08
# 127 Hours                    Nov 5, 2010         18000000.0     6.021717e+07
# 2 Guns                       Aug 2, 2013         61000000.0     1.324930e+08
# 21 Jump Street              Mar 16, 2012         42000000.0     2.028124e+08
# ...                                  ...                ...              ...
# Your Highness                Apr 8, 2011         50000000.0     2.612164e+07
# Youth                        Dec 4, 2015         13000000.0     2.400157e+07
# Zero Dark Thirty            Dec 19, 2012         52500000.0     1.346124e+08
# Zootopia                     Mar 4, 2016        150000000.0     1.019430e+09
# xXx: Return of Xander Cage  Jan 20, 2017         85000000.0     3.450334e+08
#
# [781 rows x 8 columns]

# %%
# sort by the number of user votes
joined_df.sort_values(by=['numvotes'], ascending=False).head()
# Out:
#                                         genres  category       primary_name  \
# Inception              Action,Adventure,Sci-Fi  director  Christopher Nolan
# The Dark Knight Rises          Action,Thriller  director  Christopher Nolan
# Interstellar            Adventure,Drama,Sci-Fi  director  Christopher Nolan
# Django Unchained                 Drama,Western  director  Quentin Tarantino
# The Avengers           Action,Adventure,Sci-Fi  director        Joss Whedon
#
#                        averagerating  numvotes  release_date  \
# Inception                        8.8   1841066  Jul 16, 2010
# The Dark Knight Rises            8.4   1387769  Jul 20, 2012
# Interstellar                     8.6   1299334   Nov 5, 2014
# Django Unchained                 8.4   1211405  Dec 25, 2012
# The Avengers                     8.1   1183655   May 4, 2012
#
#                        production_budget  worldwide_gross
# Inception                    160000000.0     8.355246e+08
# The Dark Knight Rises        275000000.0     1.084439e+09
# Interstellar                 165000000.0     6.663794e+08
# Django Unchained             100000000.0     4.499483e+08
# The Avengers                 225000000.0     1.517936e+09

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 781 entries, 10 Cloverfield Lane to xXx: Return of Xander Cage
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genres             781 non-null    object
#  1   category           781 non-null    object
#  2   primary_name       781 non-null    object
#  3   averagerating      781 non-null    float64
#  4   numvotes           781 non-null    int64
#  5   release_date       781 non-null    object
#  6   production_budget  781 non-null    float64
#  7   worldwide_gross    781 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 54.9+ KB

# %% [markdown]
# We will now write a for loop that goes through each films genre and adds up the gross by genre:

# %%
labels = ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Drama', 'Romance', 'Fantasy', 'Crime', 'Music', 'Thriller', 'Animation', 'History', 'Horror']
height = []

for x in labels:
    genre = joined_df['genres'].str.contains(x)
    gross = joined_df.loc[genre, ['worldwide_gross']].sum()
    height.append(gross)
    
print (labels)
print (height)
# Out:
# ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Drama', 'Romance', 'Fantasy', 'Crime', 'Music', 'Thriller', 'Animation', 'History', 'Horror']
# [worldwide_gross    1.064206e+11
# dtype: float64, worldwide_gross    1.145157e+11
# dtype: float64, worldwide_gross    4.617433e+10
# dtype: float64, worldwide_gross    5.301911e+10
# dtype: float64, worldwide_gross    4.403942e+10
# dtype: float64, worldwide_gross    9.570331e+09
# dtype: float64, worldwide_gross    2.866263e+10
# dtype: float64, worldwide_gross    1.585003e+10
# dtype: float64, worldwide_gross    4.725133e+09
# dtype: float64, worldwide_gross    2.660289e+10
# dtype: float64, worldwide_gross    3.071183e+10
# dtype: float64, worldwide_gross    2.860497e+09
# dtype: float64, worldwide_gross    9.887677e+09
# dtype: float64]

# %% [markdown]
# Now make a plot of the top-grossing genres:

# %%
#plot the total gross values by genre
height = [1.064206e+11,1.145157e+11,4.617433e+10, 5.301911e+10, 4.403942e+10, 9.570331e+09,2.866263e+10,1.585003e+10,4.725133e+09,2.660289e+10,3.071183e+10,2.860497e+09,9.887677e+09]       
x = range(13)
labels = ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Drama', 'Romance', 'Fantasy', 'Crime', 'Music', 'Thriller', 'Animation', 'History', 'Horror' ]

# Create the plot
fig, ax = plt.subplots(figsize=(12, 6))
plt.ticklabel_format(style='plain')

# Plot vertical bars of fixed width by passing x and height values to .bar() function 
ax.bar(x, height, tick_label=labels, color='green')

# Give a title to the bar graph and label the axes
ax.set_title("Top Grossing Genres")
ax.set_ylabel("Total Gross (billions)")
ax.set_yticks([0,20000000000,40000000000,60000000000,80000000000,100000000000,120000000000])
ax.set_yticklabels(['$0','$20B', '$40B', '$60B', '$80B', '$100B', '$120B'])
ax.set_xlabel("Genre");

# %% [markdown]
# The top grossing genres are Adventure, Action, and Comedy.  The former two genres do exceptionally well at the box office.

# %% [markdown]
# # 2. What time of the year is best to release a movie?

# %%
# change 'release_date' values into datetime objects
joined_df['release_date'] = pd.to_datetime(joined_df['release_date'])

# %%
# make a new 'release month' column by extracting the numeric month from the date
joined_df['release_month'] = joined_df['release_date'].dt.month

# %%
joined_df.head(10)
# Out:
#                                            genres  category  \
# 10 Cloverfield Lane          Drama,Horror,Mystery  director
# 12 Years a Slave          Biography,Drama,History  director
# 127 Hours               Adventure,Biography,Drama  director
# 2 Guns                        Action,Comedy,Crime  director
# 21 Jump Street                Action,Comedy,Crime  director
# 22 Jump Street                Action,Comedy,Crime  director
# 3 Days to Kill              Action,Drama,Thriller  director
# 30 Minutes or Less            Action,Comedy,Crime  director
# 300: Rise of an Empire         Action,Fantasy,War  director
# 42                          Biography,Drama,Sport  director
#
#                              primary_name  averagerating  numvotes  \
# 10 Cloverfield Lane      Dan Trachtenberg            7.2    260383
# 12 Years a Slave            Steve McQueen            8.1    577301
# 127 Hours                     Danny Boyle            7.6    323949
# 2 Guns                  Baltasar Kormákur            6.7    182025
# 21 Jump Street                  Phil Lord            7.2    477771
# 22 Jump Street                  Phil Lord            7.0    319504
# 3 Days to Kill                        McG            6.2     81681
# 30 Minutes or Less        Ruben Fleischer            6.1     87254
# 300: Rise of an Empire         Noam Murro            6.2    262978
# 42                        Brian Helgeland            7.5     77703
#
#                        release_date  production_budget  worldwide_gross  \
# 10 Cloverfield Lane      2016-03-11          5000000.0      108286422.0
# 12 Years a Slave         2013-10-18         20000000.0      181025343.0
# 127 Hours                2010-11-05         18000000.0       60217171.0
# 2 Guns                   2013-08-02         61000000.0      132493015.0
# 21 Jump Street           2012-03-16         42000000.0      202812429.0
# 22 Jump Street           2014-06-13         50000000.0      331333876.0
# 3 Days to Kill           2014-02-21         28000000.0       38959900.0
# 30 Minutes or Less       2011-08-12         28000000.0       40966716.0
# 300: Rise of an Empire   2014-03-07        110000000.0      330780051.0
# 42                       2013-04-12         31000000.0       97470701.0
#
#                         release_month
# 10 Cloverfield Lane                 3
# 12 Years a Slave                   10
# 127 Hours                          11
# 2 Guns                              8
# 21 Jump Street                      3
# 22 Jump Street                      6
# 3 Days to Kill                      2
# 30 Minutes or Less                  8
# 300: Rise of an Empire              3
# 42                                  4

# %%
# filter the releases by month and get the mean worldwide gross for each month
Jan = joined_df.loc[joined_df['release_month'] == 1]

Jan['worldwide_gross'].mean()
# Out:
# 120004883.60869566

# %%
# repeat for the subsequent months
Feb = joined_df.loc[joined_df['release_month'] == 2]

Feb['worldwide_gross'].mean()
# Out:
# 202246280.24074075

# %%
Mar = joined_df.loc[joined_df['release_month'] == 3]

Mar['worldwide_gross'].mean()
# Out:
# 252825845.33802816

# %%
Apr = joined_df.loc[joined_df['release_month'] == 4]

Apr['worldwide_gross'].mean()
# Out:
# 225713513.69642857

# %%
May = joined_df.loc[joined_df['release_month'] == 5]

May['worldwide_gross'].mean()
# Out:
# 417303346.375

# %%
June = joined_df.loc[joined_df['release_month'] == 6]

June['worldwide_gross'].mean()
# Out:
# 341151614.9480519

# %%
July = joined_df.loc[joined_df['release_month'] == 7]

July['worldwide_gross'].mean()
# Out:
# 283360460.1351351

# %%
Aug = joined_df.loc[joined_df['release_month'] == 8]

Aug['worldwide_gross'].mean()
# Out:
# 149711684.6885246

# %%
Sep = joined_df.loc[joined_df['release_month'] == 9]

Sep['worldwide_gross'].mean()
# Out:
# 130800996.58928572

# %%
Oct = joined_df.loc[joined_df['release_month'] == 10]

Oct['worldwide_gross'].mean()
# Out:
# 149274500.29850745

# %%
Nov = joined_df.loc[joined_df['release_month'] == 11]

Nov['worldwide_gross'].mean()
# Out:
# 275311374.79545456

# %%
Dec = joined_df.loc[joined_df['release_month'] == 12]

Dec['worldwide_gross'].mean()
# Out:
# 243354208.90666667

# %% [markdown]
# We will now plot our findings:

# %%
# plot the average box office gross per month
height = [120004883.60869566,202246280.24074075,252825845.33802816,225713513.69642857,417303346.375,341151614.9480519,283360460.1351351,149711684.6885246,130800996.58928572,149274500.29850745,275311374.79545456,243354208.90666667]       
x = range(12)
labels = ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec' ]

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
plt.ticklabel_format(style='plain')

# Plot vertical bars of fixed width by passing x and height values to .bar() function 
ax.bar(x, height, tick_label=labels, color= 'blue')

# Give a title to the bar graph and label the axes
ax.set_title("Average Gross Per Month")
ax.set_ylabel("Average Gross")
ax.set_yticks([0,100000000,200000000,300000000,400000000])
ax.set_yticklabels(['$0','$100M', '$200M', '$300M', '$400M'])
ax.set_xlabel("Month");

# %% [markdown]
# There is a tremendous spike in box office sales during May, June, and July.  A May release is preferable, so that any hit movie has the potential to sustain a box office presence throughout the summer.

# %% [markdown]
# # 3. What is the correlation between budget and profit?

# %%
# make a new column, "profit"
joined_df['profit'] = joined_df['worldwide_gross'] - joined_df['production_budget']

# %%
# sort values by 'profit'
joined_df.sort_values(by=['profit'], ascending=False).head(20)
# Out:
#                                                      genres  category  \
# Avengers: Infinity War              Action,Adventure,Sci-Fi  director
# Jurassic World                      Action,Adventure,Sci-Fi  director
# Furious 7                             Action,Crime,Thriller  director
# The Avengers                        Action,Adventure,Sci-Fi  director
# Black Panther                       Action,Adventure,Sci-Fi  director
# Jurassic World: Fallen Kingdom      Action,Adventure,Sci-Fi  director
# Frozen                           Adventure,Animation,Comedy  director
# Beauty and the Beast                 Family,Fantasy,Musical  director
# Minions                          Adventure,Animation,Comedy  director
# Avengers: Age of Ultron             Action,Adventure,Sci-Fi  director
# Incredibles 2                    Action,Adventure,Animation  director
# Iron Man 3                          Action,Adventure,Sci-Fi  director
# Aquaman                            Action,Adventure,Fantasy  director
# The Fate of the Furious               Action,Crime,Thriller  director
# Despicable Me 3                  Adventure,Animation,Comedy  director
# Captain Marvel                      Action,Adventure,Sci-Fi  director
# Transformers: Dark of the Moon      Action,Adventure,Sci-Fi  director
# Skyfall                           Action,Adventure,Thriller  director
# Despicable Me 2                  Adventure,Animation,Comedy  director
# Transformers: Age of Extinction     Action,Adventure,Sci-Fi  director
#
#                                     primary_name  averagerating  numvotes  \
# Avengers: Infinity War             Anthony Russo            8.5    670926
# Jurassic World                   Colin Trevorrow            7.0    539338
# Furious 7                              James Wan            7.2    335074
# The Avengers                         Joss Whedon            8.1   1183655
# Black Panther                       Ryan Coogler            7.3    516148
# Jurassic World: Fallen Kingdom       J.A. Bayona            6.2    219125
# Frozen                                Chris Buck            7.5    516998
# Beauty and the Beast                 Bill Condon            7.2    238325
# Minions                               Kyle Balda            6.4    193917
# Avengers: Age of Ultron              Joss Whedon            7.3    665594
# Incredibles 2                          Brad Bird            7.7    203510
# Iron Man 3                           Shane Black            7.2    692794
# Aquaman                                James Wan            7.1    263328
# The Fate of the Furious             F. Gary Gray            6.7    179774
# Despicable Me 3                       Kyle Balda            6.3     92580
# Captain Marvel                        Anna Boden            7.0    296225
# Transformers: Dark of the Moon       Michael Bay            6.2    366409
# Skyfall                               Sam Mendes            7.8    592221
# Despicable Me 2                    Pierre Coffin            7.4    344230
# Transformers: Age of Extinction      Michael Bay            5.7    283486
#
#                                 release_date  production_budget  \
# Avengers: Infinity War            2018-04-27        300000000.0
# Jurassic World                    2015-06-12        215000000.0
# Furious 7                         2015-04-03        190000000.0
# The Avengers                      2012-05-04        225000000.0
# Black Panther                     2018-02-16        200000000.0
# Jurassic World: Fallen Kingdom    2018-06-22        170000000.0
# Frozen                            2013-11-22        150000000.0
# Beauty and the Beast              2017-03-17        160000000.0
# Minions                           2015-07-10         74000000.0
# Avengers: Age of Ultron           2015-05-01        330600000.0
# Incredibles 2                     2018-06-15        200000000.0
# Iron Man 3                        2013-05-03        200000000.0
# Aquaman                           2018-12-21        160000000.0
# The Fate of the Furious           2017-04-14        250000000.0
# Despicable Me 3                   2017-06-30         75000000.0
# Captain Marvel                    2019-03-08        175000000.0
# Transformers: Dark of the Moon    2011-06-29        195000000.0
# Skyfall                           2012-11-08        200000000.0
# Despicable Me 2                   2013-07-03         76000000.0
# Transformers: Age of Extinction   2014-06-27        210000000.0
#
#                                  worldwide_gross  release_month        profit
# Avengers: Infinity War              2.048134e+09              4  1.748134e+09
# Jurassic World                      1.648855e+09              6  1.433855e+09
# Furious 7                           1.518723e+09              4  1.328723e+09
# The Avengers                        1.517936e+09              5  1.292936e+09
# Black Panther                       1.348258e+09              2  1.148258e+09
# Jurassic World: Fallen Kingdom      1.305773e+09              6  1.135773e+09
# Frozen                              1.272470e+09             11  1.122470e+09
# Beauty and the Beast                1.259200e+09              3  1.099200e+09
# Minions                             1.160336e+09              7  1.086336e+09
# Avengers: Age of Ultron             1.403014e+09              5  1.072414e+09
# Incredibles 2                       1.242521e+09              6  1.042521e+09
# Iron Man 3                          1.215392e+09              5  1.015392e+09
# Aquaman                             1.146895e+09             12  9.868946e+08
# The Fate of the Furious             1.234846e+09              4  9.848463e+08
# Despicable Me 3                     1.034728e+09              6  9.597278e+08
# Captain Marvel                      1.123062e+09              3  9.480616e+08
# Transformers: Dark of the Moon      1.123791e+09              6  9.287905e+08
# Skyfall                             1.110527e+09             11  9.105270e+08
# Despicable Me 2                     9.752168e+08              7  8.992168e+08
# Transformers: Age of Extinction     1.104039e+09              6  8.940391e+08

# %%
joined_df.describe()
# Out:
#        averagerating      numvotes  production_budget  worldwide_gross  \
# count     781.000000  7.810000e+02       7.810000e+02     7.810000e+02
# mean        6.746223  2.122158e+05       6.691253e+07     2.388938e+08
# std         0.819960  1.872533e+05       6.499592e+07     2.840231e+08
# min         1.600000  6.323100e+04       1.750000e+05     0.000000e+00
# 25%         6.300000  9.298000e+04       1.900000e+07     5.758661e+07
# 50%         6.700000  1.444420e+05       4.000000e+07     1.308189e+08
# 75%         7.300000  2.510720e+05       1.000000e+08     3.042492e+08
# max         8.800000  1.841066e+06       4.106000e+08     2.048134e+09
#
#        release_month        profit
# count     781.000000  7.810000e+02
# mean        6.889885  1.719813e+08
# std         3.417251  2.389376e+08
# min         1.000000 -9.000000e+07
# 25%         4.000000  2.326278e+07
# 50%         7.000000  7.911393e+07
# 75%        10.000000  2.172769e+08
# max        12.000000  1.748134e+09

# %%
# make scatter plot of budget and profit
fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=joined_df['profit'],
    y=joined_df['production_budget'],
    alpha=0.2,
    color='green')
plt.ticklabel_format(style='plain')
ax.set_xlabel("Profit")
ax.set_ylabel("Budget")
ax.set_title("Budget vs. Profit");

# %%
#calculate correlation coefficient
np.corrcoef(joined_df['profit'], joined_df['production_budget'])
# Out:
# array([[1.        , 0.62310025],
#        [0.62310025, 1.        ]])

# %% [markdown]
# There is a strong correlation between production budget and profit.  This means we are likely to turn a profit with our project and should be liberal with our spending.  The mean production budget is $66,912,530.  We can go well above that with our budget.

# %% [markdown]
# # 4. Who are some fan-favorite directors that we should look to hire?

# %% [markdown]
# Now let's take a look at the top 100 voted films in our database.

# %%
top100 = joined_df.sort_values(by=['numvotes'],ascending=False).head(100)

# %%
top100
# Out:
#                                                       genres  category  \
# Inception                            Action,Adventure,Sci-Fi  director
# The Dark Knight Rises                        Action,Thriller  director
# Interstellar                          Adventure,Drama,Sci-Fi  director
# Django Unchained                               Drama,Western  director
# The Avengers                         Action,Adventure,Sci-Fi  director
# ...                                                      ...       ...
# Divergent                           Action,Adventure,Mystery  director
# Horrible Bosses                                 Comedy,Crime  director
# The Conjuring                        Horror,Mystery,Thriller  director
# Elysium                                  Action,Drama,Sci-Fi  director
# Sherlock Holmes: A Game of Shadows    Action,Adventure,Crime  director
#
#                                          primary_name  averagerating  \
# Inception                           Christopher Nolan            8.8
# The Dark Knight Rises               Christopher Nolan            8.4
# Interstellar                        Christopher Nolan            8.6
# Django Unchained                    Quentin Tarantino            8.4
# The Avengers                              Joss Whedon            8.1
# ...                                               ...            ...
# Divergent                                 Neil Burger            6.7
# Horrible Bosses                           Seth Gordon            6.9
# The Conjuring                               James Wan            7.5
# Elysium                                Neill Blomkamp            6.6
# Sherlock Holmes: A Game of Shadows        Guy Ritchie            7.5
#
#                                     numvotes release_date  production_budget  \
# Inception                            1841066   2010-07-16        160000000.0
# The Dark Knight Rises                1387769   2012-07-20        275000000.0
# Interstellar                         1299334   2014-11-05        165000000.0
# Django Unchained                     1211405   2012-12-25        100000000.0
# The Avengers                         1183655   2012-05-04        225000000.0
# ...                                      ...          ...                ...
# Divergent                             399703   2014-03-21         85000000.0
# Horrible Bosses                       398695   2011-07-08         35000000.0
# The Conjuring                         397233   2013-07-19         20000000.0
# Elysium                               395572   2013-08-09        120000000.0
# Sherlock Holmes: A Game of Shadows    394189   2011-12-16        125000000.0
#
#                                     worldwide_gross  release_month  \
# Inception                              8.355246e+08              7
# The Dark Knight Rises                  1.084439e+09              7
# Interstellar                           6.663794e+08             11
# Django Unchained                       4.499483e+08             12
# The Avengers                           1.517936e+09              5
# ...                                             ...            ...
# Divergent                              2.760150e+08              3
# Horrible Bosses                        2.124176e+08              7
# The Conjuring                          3.180001e+08              7
# Elysium                                2.861921e+08              8
# Sherlock Holmes: A Game of Shadows     5.356634e+08             12
#
#                                           profit
# Inception                           6.755246e+08
# The Dark Knight Rises               8.094391e+08
# Interstellar                        5.013794e+08
# Django Unchained                    3.499483e+08
# The Avengers                        1.292936e+09
# ...                                          ...
# Divergent                           1.910150e+08
# Horrible Bosses                     1.774176e+08
# The Conjuring                       2.980001e+08
# Elysium                             1.661921e+08
# Sherlock Holmes: A Game of Shadows  4.106634e+08
#
# [100 rows x 10 columns]

# %% [markdown]
# Now let's look at the representation of directors in the top 100

# %%
top100['primary_name'].value_counts().head(20)
# Out:
# Christopher Nolan        4
# Matthew Vaughn           3
# Anthony Russo            3
# Joss Whedon              3
# Peter Jackson            3
# David O. Russell         2
# Baz Luhrmann             2
# Denis Villeneuve         2
# Alejandro G. Iñárritu    2
# Neil Burger              2
# Quentin Tarantino        2
# Damien Chazelle          2
# Martin Scorsese          2
# James Mangold            2
# David Fincher            2
# Zack Snyder              2
# Ridley Scott             2
# Jean-Marc Vallée         1
# J.J. Abrams              1
# Joe Johnston             1
# Name: primary_name, dtype: int64

# %% [markdown]
# Let's compare a few popular directors:

# %%
# filter rows for only Christopher Nolan films
CN = top100.loc[top100['primary_name'] == 'Christopher Nolan']
CN
# Out:
#                                         genres  category       primary_name  \
# Inception              Action,Adventure,Sci-Fi  director  Christopher Nolan
# The Dark Knight Rises          Action,Thriller  director  Christopher Nolan
# Interstellar            Adventure,Drama,Sci-Fi  director  Christopher Nolan
# Dunkirk                   Action,Drama,History  director  Christopher Nolan
#
#                        averagerating  numvotes release_date  \
# Inception                        8.8   1841066   2010-07-16
# The Dark Knight Rises            8.4   1387769   2012-07-20
# Interstellar                     8.6   1299334   2014-11-05
# Dunkirk                          7.9    466580   2017-07-21
#
#                        production_budget  worldwide_gross  release_month  \
# Inception                    160000000.0     8.355246e+08              7
# The Dark Knight Rises        275000000.0     1.084439e+09              7
# Interstellar                 165000000.0     6.663794e+08             11
# Dunkirk                      150000000.0     4.998374e+08              7
#
#                             profit
# Inception              675524642.0
# The Dark Knight Rises  809439099.0
# Interstellar           501379375.0
# Dunkirk                349837368.0

# %%
CN.describe()

# AVERAGE Rating 8.425
# Out:
#        averagerating      numvotes  production_budget  worldwide_gross  \
# count       4.000000  4.000000e+00       4.000000e+00     4.000000e+00
# mean        8.425000  1.248687e+06       1.875000e+08     7.715451e+08
# std         0.386221  5.728622e+05       5.866572e+07     2.495870e+08
# min         7.900000  4.665800e+05       1.500000e+08     4.998374e+08
# 25%         8.275000  1.091146e+06       1.575000e+08     6.247439e+08
# 50%         8.500000  1.343552e+06       1.625000e+08     7.509520e+08
# 75%         8.650000  1.501093e+06       1.925000e+08     8.977533e+08
# max         8.800000  1.841066e+06       2.750000e+08     1.084439e+09
#
#        release_month        profit
# count            4.0  4.000000e+00
# mean             8.0  5.840451e+08
# std              2.0  2.007136e+08
# min              7.0  3.498374e+08
# 25%              7.0  4.634939e+08
# 50%              7.0  5.884520e+08
# 75%              8.0  7.090033e+08
# max             11.0  8.094391e+08

# %%
CN['numvotes'].sum()
# NUMVOTES 4994749
# AVG TOTAL GROSS $771,545,100
# Out:
# 4994749

# %%
# filter rows for only Russo Brothers films
RU = top100.loc[top100['primary_name'] == 'Anthony Russo']
RU
# Out:
#                                                       genres  category  \
# Avengers: Infinity War               Action,Adventure,Sci-Fi  director
# Captain America: The Winter Soldier  Action,Adventure,Sci-Fi  director
# Captain America: Civil War           Action,Adventure,Sci-Fi  director
#
#                                       primary_name  averagerating  numvotes  \
# Avengers: Infinity War               Anthony Russo            8.5    670926
# Captain America: The Winter Soldier  Anthony Russo            7.8    666252
# Captain America: Civil War           Anthony Russo            7.8    583507
#
#                                     release_date  production_budget  \
# Avengers: Infinity War                2018-04-27        300000000.0
# Captain America: The Winter Soldier   2014-04-04        170000000.0
# Captain America: Civil War            2016-05-06        250000000.0
#
#                                      worldwide_gross  release_month  \
# Avengers: Infinity War                  2.048134e+09              4
# Captain America: The Winter Soldier     7.144019e+08              4
# Captain America: Civil War              1.140069e+09              5
#
#                                            profit
# Avengers: Infinity War               1.748134e+09
# Captain America: The Winter Soldier  5.444019e+08
# Captain America: Civil War           8.900694e+08

# %%
RU['numvotes'].sum()
# Out:
# 1920685

# %%
RU.describe()
# AVERAGE Rating 8.03
# NUMVOTES 1920685
# AVG TOTAL GROSS $1,300,869,000
# Out:
#        averagerating       numvotes  production_budget  worldwide_gross  \
# count       3.000000       3.000000       3.000000e+00     3.000000e+00
# mean        8.033333  640228.333333       2.400000e+08     1.300869e+09
# std         0.404145   49177.675935       6.557439e+07     6.812509e+08
# min         7.800000  583507.000000       1.700000e+08     7.144019e+08
# 25%         7.800000  624879.500000       2.100000e+08     9.272357e+08
# 50%         7.800000  666252.000000       2.500000e+08     1.140069e+09
# 75%         8.150000  668589.000000       2.750000e+08     1.594102e+09
# max         8.500000  670926.000000       3.000000e+08     2.048134e+09
#
#        release_month        profit
# count       3.000000  3.000000e+00
# mean        4.333333  1.060869e+09
# std         0.577350  6.197759e+08
# min         4.000000  5.444019e+08
# 25%         4.000000  7.172357e+08
# 50%         4.000000  8.900694e+08
# 75%         4.500000  1.319102e+09
# max         5.000000  1.748134e+09

# %%
# filter rows for only Peter Jackson films
PJ = top100.loc[top100['primary_name'] == 'Peter Jackson']
PJ
# Out:
#                                                              genres  category  \
# The Hobbit: An Unexpected Journey          Adventure,Family,Fantasy  director
# The Hobbit: The Desolation of Smaug               Adventure,Fantasy  director
# The Hobbit: The Battle of the Five Armies         Adventure,Fantasy  director
#
#                                             primary_name  averagerating  \
# The Hobbit: An Unexpected Journey          Peter Jackson            7.9
# The Hobbit: The Desolation of Smaug        Peter Jackson            7.8
# The Hobbit: The Battle of the Five Armies  Peter Jackson            7.4
#
#                                            numvotes release_date  \
# The Hobbit: An Unexpected Journey            719629   2012-12-14
# The Hobbit: The Desolation of Smaug          565563   2013-12-13
# The Hobbit: The Battle of the Five Armies    438621   2014-12-17
#
#                                            production_budget  worldwide_gross  \
# The Hobbit: An Unexpected Journey                250000000.0     1.017004e+09
# The Hobbit: The Desolation of Smaug              250000000.0     9.603669e+08
# The Hobbit: The Battle of the Five Armies        250000000.0     9.455776e+08
#
#                                            release_month       profit
# The Hobbit: An Unexpected Journey                     12  767003568.0
# The Hobbit: The Desolation of Smaug                   12  710366855.0
# The Hobbit: The Battle of the Five Armies             12  695577621.0

# %%
PJ.describe()
# AVERAGE Rating 7.7
# NUMVOTES 1723813
# AVG TOTAL GROSS $974,316,000
# Out:
#        averagerating       numvotes  production_budget  worldwide_gross  \
# count       3.000000       3.000000                3.0     3.000000e+00
# mean        7.700000  574604.333333        250000000.0     9.743160e+08
# std         0.264575  140722.007154                0.0     3.770081e+07
# min         7.400000  438621.000000        250000000.0     9.455776e+08
# 25%         7.600000  502092.000000        250000000.0     9.529722e+08
# 50%         7.800000  565563.000000        250000000.0     9.603669e+08
# 75%         7.850000  642596.000000        250000000.0     9.886852e+08
# max         7.900000  719629.000000        250000000.0     1.017004e+09
#
#        release_month        profit
# count            3.0  3.000000e+00
# mean            12.0  7.243160e+08
# std              0.0  3.770081e+07
# min             12.0  6.955776e+08
# 25%             12.0  7.029722e+08
# 50%             12.0  7.103669e+08
# 75%             12.0  7.386852e+08
# max             12.0  7.670036e+08

# %% [markdown]
# Now plot the average box office gross by director:

# %%
height = [7.715451e+08,9.743160e+08,1.300869e+09]       
x = range(3)
labels = ['Christopher Nolan', 'Peter Jackson', 'Russo Brothers']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
plt.ticklabel_format(style='plain')

# Plot vertical bars of fixed width by passing x and height values to .bar() function 
ax.bar(x, height, tick_label=labels, color=['green','tan','lime'])

# Give a title to the bar graph and label the axes
ax.set_title("Average Gross Per Film")
ax.set_ylabel("Average Gross (billions)")
ax.set_yticks([0,200000000,400000000,600000000,800000000,1000000000,1200000000])
ax.set_yticklabels(['$0','$200M', '$400M', '$600M', '$800M', '$1B','$1.2B' ])
ax.set_xlabel("Director");

# %% [markdown]
# Though the Peter Jackson and Russo Brothers films are higher grossing, they are all respectively in the same genre.  The Jackson films are all Lord of the Rings sequels and the Russo films are all Marvel Superhero films backed by Disney.  These films have the advantage of being sequels to popular franchises, using established source material.  As a new studio Microsoft is unlikely to replicate Peter Jackson or the Russo Brothers' success without Tolkien or Marvel licensing.

# %%
# plot the number of IMDB votes by director
height = [CN['numvotes'].sum(),PJ['numvotes'].sum(),RU['numvotes'].sum()]       
x = range(3)
labels = ['Christopher Nolan', 'Peter Jackson', 'Russo Brothers']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))


# Plot vertical bars of fixed width by passing x and height values to .bar() function 
ax.bar(x, height, tick_label=labels, color=['green','tan','lime'])

# Give a title to the bar graph and label the axes
ax.set_title("IMDB Vote Totals")
ax.set_ylabel("Number of Votes")
ax.set_yticks([0,1000000,2000000,3000000,4000000,5000000])
ax.set_yticklabels(['0','1M', '2M', '3M', '4M', '5M'])
ax.set_xlabel("Director");

# %% [markdown]
# Christopher Nolan is a more ideal director.  Nolan's filmography is more versatile, spanning six genres.  He has seen success both with (Batman films) and without licensed material.  According to IMDB, fans are more engaged with Nolan's films compared to other directors.  The top 3 user voted films of all time, Inception, The Dark Knight Rises, and Interstellar, are all Christopher Nolan films.  He also has the highest average rating for his popular films- averaging an 8.425, compared to Jacksons's 7.7 and the Russo Brothers 8.03.

# %% [markdown]
# ## Conclusions
#
#   I recommend that Microsoft Studios:
#   - collaborate with Christopher Nolan
#   - release a big budget film that is heavy on Action & Adventure
#   - aim for a May release
#
# Still, there are some reasons that this recommendation may not fully solve the business problem:
#
# - Release window may be overcrowded by other films.
# - Analysis doesn't make predictions far out into the future.
# - Older films will have less online engagement on IMDB.
# - It would be helpful to additional data: movie streaming numbers, digital purchase and rental sales, VHS and DVD sales, and data during the pandemic and the post-pandemic recovery period.
